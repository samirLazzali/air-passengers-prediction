# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv('https://raw.githubusercontent.com/pleydier/Air_Passengers_Answer/master/Soumission%20Ramp/LightGBM/external_data.csv')

# %%
my_extern = pd.read_csv('submissions/submit/external_data.csv', index_col=0)

# %%
my_extern.head()
# Out:
#          Date AirPort  Max TemperatureC  Mean TemperatureC  Min TemperatureC  \
# 0  2011-09-01     ATL                35                 29                24
# 1  2011-09-02     ATL                36                 29                22
# 2  2011-09-03     ATL                35                 29                23
# 3  2011-09-04     ATL                27                 24                22
# 4  2011-09-05     ATL                26                 24                22
#
#    Dew PointC  MeanDew PointC  Min DewpointC  Max Humidity  Mean Humidity  \
# 0          21              18             14            79             56
# 1          17              15             14            61             46
# 2          17              16             14            64             47
# 3          22              19             16            93             72
# 4          23              22             20            94             91
#
# ...

# %%
data.head()
# Out:
#          Date AirPort  Max TemperatureC  Mean TemperatureC  Min TemperatureC  \
# 0  2011-09-01     ATL                35                 29                24
# 1  2011-09-02     ATL                36                 29                22
# 2  2011-09-03     ATL                35                 29                23
# 3  2011-09-04     ATL                27                 24                22
# 4  2011-09-05     ATL                26                 24                22
#
#    Dew PointC  MeanDew PointC  Min DewpointC  Max Humidity  Mean Humidity  \
# 0          21              18             14            79             56
# 1          17              15             14            61             46
# 2          17              16             14            64             47
# 3          22              19             16            93             72
# 4          23              22             20            94             91
#
# ...

# %%
import problem

# %%
X,y = problem.get_train_data()

# %%
my_extern
# Out:
#              Date AirPort  Max TemperatureC  Mean TemperatureC  \
# 0      2011-09-01     ATL                35                 29
# 1      2011-09-02     ATL                36                 29
# 2      2011-09-03     ATL                35                 29
# 3      2011-09-04     ATL                27                 24
# 4      2011-09-05     ATL                26                 24
# ...           ...     ...               ...                ...
# 11035  2013-03-01     LGA                 7                  5
# 11036  2013-03-02     LGA                 4                  2
# 11037  2013-03-03     LGA                 4                  2
# 11038  2013-03-04     LGA                 5                  2
# 11039  2013-03-05     LGA                 9                  5
#
#        Min TemperatureC  Dew PointC  MeanDew PointC  Min DewpointC  \
# 0                    24          21              18             14
# 1                    22          17              15             14
# ...

# %%
view = X.merge(data[["Net_domestic_migration_rate_per_1000_hab",
                     'city_population',"Median_income",'Date','AirPort']], how='left', 
        left_on=["DateOfDeparture", "Arrival"],
       right_on=["Date",'AirPort'])

# %%
np.corrcoef(y,view["Average Wage"])
# Out:
# array([[ 1.        , -0.01484184],
#        [-0.01484184,  1.        ]])

# %%
extern_augmented = my_extern.merge(data[["Net_domestic_migration_rate_per_1000_hab",
                     'city_population',"Median_income",'Date','AirPort']], how='left', 
        on=["Date", "AirPort"])

# %%
extern_augmented.to_csv('extern.csv')

# %%
test = X.merge(extern_augmented, how='left', 
        left_on=["DateOfDeparture", "Arrival"],
       right_on=["Date",'AirPort'])

# %%
for i in test :
    try : 
        print(i)
        print(np.corrcoef(y,test[i]))
    except :
        pass
# Out:
# DateOfDeparture
# Departure
# Arrival
# WeeksToDeparture
# [[1.         0.16345274]
#  [0.16345274 1.        ]]
# std_wtd
# [[1.         0.10923102]
#  [0.10923102 1.        ]]
# Date
# AirPort
# Max TemperatureC
# [[1.         0.08275744]
#  [0.08275744 1.        ]]
# Mean TemperatureC
# [[1.         0.09895804]
#  [0.09895804 1.        ]]
# Min TemperatureC
# [[1.         0.11446138]
#  [0.11446138 1.        ]]
# Dew PointC
# [[1.         0.14645041]
#  [0.14645041 1.        ]]
# MeanDew PointC
# [[1.         0.14037778]
#  [0.14037778 1.        ]]
# Min DewpointC
# [[1.         0.13219435]
#  [0.13219435 1.        ]]
# Max Humidity
# [[1.         0.09061961]
#  [0.09061961 1.        ]]
# Mean Humidity
# [[1.         0.08344611]
#  [0.08344611 1.        ]]
# Min Humidity
# [[1.         0.06781617]
#  [0.06781617 1.        ]]
# Max Sea Level PressurehPa
# [[ 1.         -0.05989081]
#  [-0.05989081  1.        ]]
# Mean Sea Level PressurehPa
# [[ 1.       -0.037448]
# ...
